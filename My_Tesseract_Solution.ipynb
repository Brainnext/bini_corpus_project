# %%
# !git clone https://github.com/Brainnext/bini_corpus_project.git
# Out:
# Cloning into 'bini_corpus_project'...
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 7 (delta 1), reused 3 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (7/7), 9.23 KiB | 9.23 MiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %%
# !ls
# Out:
# bini_corpus_project  corpora.ipynb  README.md

# %%
# %cd bini_corpus_project
# Out:
# /content/bini_corpus_project

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/bini_corpus_project/.git/

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Change the file names to match yours
# !cp "/content/drive/My Drive/Colab Notebooks/My_Tesseract_Solution.ipynb" "/content/bini_corpus_project/My_Tesseract_Solution.ipynb"

# %%
# !git add bini_corpora_new.ipynb
# Out:
# fatal: pathspec 'bini_corpora_new.ipynb' did not match any files
